# %% [markdown]
# <a href="https://colab.research.google.com/github/yustinaivanova/math_netology/blob/master/dz_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Математики для data science.
# # Домашнее задание 1.

# %% [markdown]
# **Задание на отображение множеств.**

# %% [markdown]
# **Задание 1.**

# %% [markdown]
# Написать функцию отображения элементов одного множества в другое. Первое множество - художники, второе множество - картины художников.
# Множество художников - Серов, Левитан, Репин, Васнецов, Шишкин.
# Множество картин - "Утро в сосновом бору", "Богатыри", "Золотая осень", "Девочка с персиками", "Запорожцы", "Буралки на Волге", "Март", "Алёнушка".

# %% [markdown]
# тут не совсем понял это задание, ну вот создали словарь, теперь можем написать шишкина и покажется что он написал.
# А дальше то что?
# можно например написать функцию которая будет по картине искать художников, как например "утро в сосновом бору"

# %%
def name_artists(picture):
    artists = {
    'Шишкин':['Утро в сосновом бору'],
    'Васнецов':['Богатыри','Алёнушка'],
    'Левитан':['Золотая осень', 'Март'],
    'Серов':['Девочка с персиками'],
    'Репин':['Запорожцы','Бурлаки на Волге'],
    'Савицкий':['Утро в сосновом бору']
    }
    ans = []
    for i in list(artists):
        for y in artists[i]:
            if y == picture:
                ans.append(str(i))    
    return ans

name_artists('Утро в сосновом бору')
# Out:
# ['Шишкин', 'Савицкий']

# %% [markdown]
# **Полиномиальные функции.**

# %% [markdown]
# **Задание 2**. Найти из следующих функций те, которые являются полиномиальной функцией.

# %% [markdown]
# *  $$f(x)=\frac{1}{2}x^{6}-1\frac{5}{6}x+\frac{1}{3}$$
# *  $$f(x)=\frac{3x^{6}-11x+2}{6}$$
# *  $$f(x)=\frac{3x^{6}-11x+2}{6x}$$
# *  $$f(x)=x^{5}-3x^{2}+7x^{-2}$$
# *  $$f(x)=(5x^{2}-2)^3-\frac{1}{2}x^{3}$$
# *  $$f(x)=(1+\sqrt{x})^{3}-5(1+\sqrt{x})$$
# *  $$f(x)=\pi $$

# %% [markdown]
# мне на работе коллеги подсказали, что полином, это сумма x в положительной рациональной степени
# $$f(x)=\frac{1}{2}x^{6}-1\frac{5}{6}x+\frac{1}{3}$$
# $$f(x)=\frac{3x^{6}-11x+2}{6}$$
# $$f(x)=\frac{3x^{6}-11x+2}{6x}$$
# $$f(x)=(5x^{2}-2)^3-\frac{1}{2}x^{3}$$
# $$f(x)=\pi $$
# А оставшиеся не содержат, либо умножения, либо сложения, а последняя я вообще не понимаю как функцией называется, просто пи
# $$f(x)=x^{5}-3x^{2}+7x^{-2}$$
#
# $$f(x)=(1+\sqrt{x})^{3}-5(1+\sqrt{x})$$

# %%
from math import pow
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

def func(x,num): # возвращается нужная функция
    global num_func # льщу себя надеждой, что вы такое не видели, что так можно делать, потому что это я сам придумал)
    #я о том, чтобы можно было в словарь, вставлять функции) 
    num_func = {
        1:1/2*pow(x,6)-1*5/6*x+1/3,
        2:(3*pow(x,6)-11*x+2)/6,
        3:(3*pow(x,6)-11*x+2)/6*x,
        4:pow(x,5)-3*pow(x,2)+7*pow(x,-2),
        5:pow((5*pow(x,2)-2),3)-1/2*pow(x,3),
        6:(1+x**0.5)**3-5*(1+x**0.5)
    }
    y=num_func[num]
    return y

# создаем вектор x
x = np.linspace(-3.0, 3.0, 100)
# на основе вектора x строим значения для векторов

def array_y(num): # возвращаем массив y в зависимости от нужного
    y = [func(x[i],num) for i in range(len(x))]
    return y

plt.figure(figsize=(15, 12))

for i in range(1,7): # ну а тут элегантно строим сразу все, хотя возможно это не имеет отношения к домашке...
    plt.subplot(230+i)
    plt.plot(x, array_y(i))
    plt.title(f'График функции {i}')
    plt.hlines(0, -3,3, color='g')
    plt.ylabel('y')
    plt.xlabel('x')
# Out:
# C:\Users\Paper Planes\Anaconda3\lib\site-packages\ipykernel_launcher.py:16: RuntimeWarning: invalid value encountered in double_scalars
#   app.launch_new_instance()

# %% [markdown]
# **Задание 3**. Раскрыть скобки для следующего полинома $$(2x+1)^{2}(x-1)-x(4x^{2}-1)-x(4x^{2}-1)=ax^3+bx^2+cx+d$$ найти коэффициенты для a, b, c, d.

# %% [markdown]
# $$(2x+1)^{2}(x-1)-x(4x^{2}-1)-x(4x^{2}-1)=ax^3+bx^2+cx+d$$
# $$2x^{2}+4x+1*(x-1)-4x^{2}*x+x-4x^{2}*x+x$$
# $$2x^{2}+4x+1*(x-1)-4x^{2}*x+2x-4x^{2}*x$$

# %% [markdown]
# Для данного задания полезно использовать следующие формулы сокращенного умножения:
# ![alt text](https://sun9-38.userapi.com/c851232/v851232044/19c5b0/7Yy6qz-MUHA.jpg)

# %% [markdown]
# Чему равна степень полинома?

# %% [markdown]
# Нарисовать график для полинома.

# %% [markdown]
# **Задание 4**.
# Для заданных функций найти подходящий график (не все функции имеют график):
# $\frac{3}{4}x-1$,  $\frac{3}{4}x+2$, $2-2x$, $2+2x$, $\frac{1}{4}(x+1)^{2}-2 $, $\frac{1}{4}(x-1)^2-2$, $(x-1)(x-3)$, $(x+1)(x+3)$, $2-x^2$, $2-\frac{1}{4}x^2$

# %%
def func(x,num): # возвращается нужная функция
    num_func = {
        1:3/4*x-1,
        2:3/4*x+2,
        3:2-2*x,
        4:2+2*x,
        5:1/4*pow((x+1),2)-2,
        6:1/4*pow((x-1),2)-2,
        7:(x-1)*(x-3),
        8:(x+1)*(x-3),
        9:2-x**2,
        10:2-1/4*pow(x,2)
    }
    y=num_func[num]
    return y

# создаем вектор x
x = np.linspace(-3.0, 3.0, 100)
# на основе вектора x строим значения для векторов

def array_y(num): # возвращаем массив y в зависимости от нужного
    y = [func(x[i],num) for i in range(len(x))]
    return y

plt.figure(figsize=(15, 11))

for i in range(1,10): # ну а тут элегантно строим сразу все, хотя возможно это не имеет отношения к домашке...
    plt.subplot(330+i)    
    plt.plot(x, array_y(i))
    plt.title(f'График функции {i}')
    plt.hlines(0, -3,3, color='g')
    plt.vlines(0, min(array_y(i)), max(array_y(i)), color='g')
    plt.ylabel('y')

    
plt.figure(figsize=(5, 4))    
plt.plot(x, array_y(10))
plt.title(f'График функции {10}')
plt.hlines(0, -3,3, color='g')
plt.vlines(0, min(array_y(10)), max(array_y(10)), color='g')
plt.ylabel('y')
plt.xlabel('x')
# Out:
# Text(0.5, 0, 'x')

# %% [markdown]
# номер со скобкой соответсвует номеру графика в предыдущей ячейке<br>
# 1) 5<br>2) -<br>3) 1<br>4) -<br>5) 4<br>6) -<br>7) -<br>8) -<br>9) 3<br>10) -<br>

# %% [markdown]
# ![alt text](https://pp.userapi.com/c855532/v855532908/aadd4/uWjIZGDfw0s.jpg)

# %% [markdown]
# **Задание 5.** Найти минимальную степень следующего полинома:
#
# ![alt text](https://pp.userapi.com/c855532/v855532908/aadcd/PZdPYTQT02A.jpg)

# %% [markdown]
# **Задания повышенного уровня**

# %% [markdown]
# Почему следующие функции не являются полиномиальными?
# $$y=5x^{-2}+1$$ отрицательная степень
# $$y=3x^{1/2}+2$$ не рациональное число
# $$y=(5x+1)/(3x)$$ будет отрицательная степень

# %% [markdown]
# Найдите наибольшее и наименьшее значение функции $y = x^3 + 2x^2 + x + 3 $ на отрезке [-4;-1].

# %%
def func(x,num): # возвращается нужная функция
    num_func = {
        1:pow(x,3)+2*pow(x,2)+x+3
    }
    y=num_func[num]
    return y

# создаем вектор x
x = np.linspace(-4.0, -1.0, 100)
# на основе вектора x строим значения для векторов

def array_y(num): # возвращаем массив y в зависимости от нужного
    y = [func(x[i],num) for i in range(len(x))]
    return y

plt.figure(figsize=(15, 11))

print(f'max = {max(array_y(i))} \nmin ={min(array_y(i))}')
for i in range(1,2): 
    plt.plot(x, array_y(i))
    plt.title(f'График функции {i}')
    plt.ylabel('y')
    plt.xlabel('x')
    plt.show()
# Out:
# max = 3.0
# min =-33.0

# %% [markdown]
# Пример линейной регрессии - это применение полиномов на практике. В следующем примере дан датасет x, y, сгенерированный рандомно. Мы можем использовать линейную регрессию, чтобы предсказать значение переменной y от x.

# %%
import numpy as np
import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression

np.random.seed(0)
x = 2 - 3 * np.random.normal(0, 1, 20)
y = x - 2 * (x ** 2) + 0.5 * (x ** 3) + np.random.normal(-3, 3, 20)

# transforming the data to include another axis
x = x[:, np.newaxis]
y = y[:, np.newaxis]

model = LinearRegression()
model.fit(x, y)
y_pred = model.predict(x)

plt.scatter(x, y, s=10)
plt.plot(x, y_pred, color='r')
plt.show()

# %% [markdown]
# В данном примере найден полином первой степени. Как можно улучшить данную модель? Написать пример.

# %% [markdown]
# Использовать полиномиальную модель, так и улучшить.

# %%
from sklearn.preprocessing import PolynomialFeatures 

np.random.seed(0)
x = 2 - 3 * np.random.normal(0, 1, 20)
y = x - 2 * (x ** 2) + 0.5 * (x ** 3) + np.random.normal(-3, 3, 20)

# transforming the data to include another axis
x = x[:, np.newaxis]
y = y[:, np.newaxis]  
poly = PolynomialFeatures(degree = 3) 
X_poly = poly.fit_transform(x) 
  
poly.fit(X_poly, y) 
lin2 = LinearRegression()
model = lin2.fit(X_poly, y) 

y_pred = model.predict(poly.fit_transform(x))
plt.scatter(x, y, marker='o')
plt.scatter(x, y_pred, marker='x')
plt.title('LSTAT')
plt.xlabel('LSTAT')
plt.ylabel('MEDV')
plt.legend(['исходные данные', 'полином 3ой степени'])
plt.show()
